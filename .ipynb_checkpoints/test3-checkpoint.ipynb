# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# N(t) = k*exp(2t)*exp(-cos(t))

x = np.linspace(0, 4*np.pi)
y = np.exp(x)*np.exp(-np.cos(x))
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_yscale('log')
ax.plot(x, y)

plt.show()
