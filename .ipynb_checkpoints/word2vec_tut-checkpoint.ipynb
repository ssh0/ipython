# %%
from gensim.models import word2vec

# %%
text = []
with open('/home/shotaro/Dropbox/log.txt') as f:
    for s in f.readlines():
        text += s.split()[1:]
with open('/home/shotaro/copus.txt', 'w') as w:
    for t in text:
        w.write(t)
        w.write(" ")

# %%
data = word2vec.Text8Corpus('/home/shotaro/copus.txt')

# %%
# !cat '/home/shotaro/copus.txt'
# Out:
# シェルスクリプト 言語 ubuntu シェルスクリプト 言語 ubuntu シェルスクリプト 置き場所 changelog ubuntu ubuntu アプリ 慶應 入試 家計簿 シェルスクリプト csv zenity date UNIX zenity --filename gui シェルスクリプト アイテムボックス zenity アプリ crontab M-D yama_ko Vimeo 渋谷 天気 test 四角形 面積 渋谷駅 本屋 渋谷 天気 渋谷 古本屋 gnomelook.org シェルスクリプト if シェルスクリプト gnuplot gnuplot 凡例 firefox シェルスクリプト fresno awk 置き換え awk 置き換え case awk シェルスクリプト grep シェルスクリプト シェルスクリプト case wikipedia 探す zenity するめいか スルメイカ するめいか ありがとう バレンタインデー perfume さいたまスーパーアリーナ すごい capsule するめいか 作業用動画 トシゾー firefox ブックマーク gedit スキーム ランドセル test -t シェルスクリプト 文字列 firefox オプション するめいか -p するめいか -p もしかして -p uuu p もしかしてだけど -P 沸騰水型原子炉 沸騰水型原子炉 perfume 沸騰水型原子炉 フラクタル図形 直下掘り ゆったりゆとりクラフト 建国記念日 symbolic firefox -recording http://d.hatena.ne.jp/gepuro/20121218 cillia ubuntu ファイル名 ニコニコ技術部 君を乗せて Python どうしてこうなった 新海誠 トラックボール 作業用BGM ワンライナー シェルスクリプト 言語 sed https://www.facebook.com/ https://www.facebook.com/ https://www.facebook.com/ gnome環境 wm infobar+a02 速読練習用 zenity 検索フォーム シェルスクリプト if test ubuntu cinii するめいか firefox 電気 もしかして aiueo 鰊 アカニシン ドラえもん シェルスクリプト 終了 トシゾー ドラえもん ドラえもん ドラえもん どらえもん モンスターズインク トシゾー トシゾー トシゾー ドラえもん トシゾー ニコニコ動画 もったいないとランド するめいか もったいないとランド もったいないとらんど もったいないとらんど 日本人 日本 日本 if シェルスクリプト フラクタル 不動点,数理,,,,,,,,,,,1999 統計 気象 if シェルスクリプト 日本海 トシゾー ゆったりゆとりクラフト 湯浅 ,,湯浅,,,,,,,,,, ,,湯浅,早稲田大学,,,,,,,,, ,,湯浅+一哉,,,,,,,,,, ,,山崎+義弘,,,,,,,,,, ubuntu 音量 gconf シェルスクリプト if $NONE するめいか ,,,早稲田大学,,,,,,,,, 作業用BGM のんのんびより google 読み上げ s2x.py download minecraft mobizen 亀憑きゆかり userscript touch シェルスクリプト softallk linux ドラえもん これはひどい するめいか するめいか sed 使い方 シェルスクリプト 天気 水槽 ペンタブ 無線 ペンタブ 通常使い is05 HDMI これからの話 aa トシゾー 統計 シェルスクリプト,,,,,,,,,,,, 合成音声 日常のラヂオ ニコニコ動画 xml firefox ubuntu キャッシュ mv ファイルオペランド 自動読み上げ サンプル open-jtalk スルメイカ ソナーのピング音 gnome 効果音 もしかすると lifebook uh75/k コネクタ ubuntu MMDAgent while シェルスクリプト vimeo 正規表現 トシゾー 巡回 シェルスクリプト mail コマンド 使い方 chmod オプション シェルスクリプト 別プロセス コーヒー中毒 口癖 口癖 マインクラフト ラインの乙女 TM-150r スクロール ubuntu トシゾー スルメイカ ubuntu トラックボール スクロール だいじょばない lifebook uh75/k スクリーン http://www.logicool.co.jp/downloads ,,,,Science,,,,,,,, めい めい トシゾー クッキークリッカー クッキークリッカー クッキークリッカー marbleman trackball クッキークリッカー 攻略 トシゾー クッキークリッカー 攻略 yurie ファミマに入店したらテンションあがった 野生の中田ヤスタカ tm 150r クッキークリッカー トシゾー 無料 フォント モリサマー モリサマー http://www24.atwiki.jp/myfavoritepcsettings/m/pages/271.html?guid=on http://www24.atwiki.jp/myfavoritepcsettings/m/pages/271.html?guid=on ubuntu スワップ 有効 モリサマー ドラえもん 浅田真央 シェルスクリプト ウェブ radiko http://www.drk7.jp/weather/xml/13.xml トシゾー シェルスクリプト ファイル 書き換え 円学梅花堂 壁紙 linux もしかしなくても もしかしなくても dogtail actionaz taildog ナマコ 皮 ナマコ このわた 複雑度 国立大学 入試 radiko 連結鎖モデル リミットサイクル マトリョシカ mix マインドマップ ubuntu gnome-look.org トシゾー クッキークリッカー 実績 ubuntu スプラッシュ 自作pc hardoff 東京 photoshop 流用 作ってみた -y　アタッシュケース PC ubuntu デスクトップ 壁紙 octet-stream 自動 マウント ubuntu swap fstab browser.cache.memory_limit http://d.hatena.ne.jp/gepuro/20121218 gnuplot latex 数式 トシゾー ubuntu 最適化 スルメイカ ubuntu マウント utf8 ゴーギャン 新印象派 壁紙 新印象派 壁紙 抽象 1920x1080 バベルの塔 解釈 バベルの塔 グローバル化 intext:"yahoo.com" http://www.oreilly.com/catalog/googlehks/ 2ch IT "今日もおつかれさまでした" blog モニタ 内部 壁紙 それこそ AND 口癖 国を想う智慧 トシゾー ubuntu メモリ 使用率 vm.swappiness 鍵ID ubuntu 以下の鍵 ID に対して利用可能な公開鍵がありません 以下の鍵 ID に対して利用可能な公開鍵がありません: 40976EAF437D05B5 compiz ウィンドウ 配置 sed リネーム 努力の方向音痴 ゲル 相転移 ubuntu FaganFinder ワイヤレス イヤホン unity unity 通知 通知 音量 robot ant ubuntu メモリ 初期化 トシゾー ubuntu オンラインアカウント 袋開ける 耳痛い puppy linux ビット深度 ubuntu studio ALSA PulseAudio ビット深度 ビットレート sgt. 家入レオ 新宿御苑 ubuntu xfs gparted eddie bauer sony ハイレゾ ubuntu リモートログイン トシゾー sudo sed -i 's/UTC=yes/UTC=no/g' /etc/default/rcS "sudo sed -i 's/UTC=yes/UTC=no/g' /etc/default/rcS" ubuntu コマンド 履歴 ubuntu 粘菌 粘菌,ネットワーク,,,,,,,,,,1992,2014 するめいか apple こんにちは オーバークロック メリット ubuntu handy man 考察 googlemap 慶應 日吉寮 awk クッピーラムネ 中二病でも恋がしたい！ ニコ生 かな入力 知的生活 話しかけられ 嬉しい 愛国心 ランキング 話しかける 粘菌,,,,,,,,,,,1992,2010 perfume プログラミング 環境経済学 "村木洋介" スタバ ドヤ顔 楽天 みんなの就職活動日記 perfume 3/15 東京スカパラダイスオーケストラ yahoo リアルタイム検索 映画 トシゾー トシゾー トシゾー シェルスクリプト HTML デレ期 長男 末っ子 デュアルブート メモリ gnuplot 円グラフ 画面の明るさ　ubuntu crontab 設定 同次式 シェルスクリプト 回答 html シェルスクリプト radiko ロシア ウクライナ 男 まつげ 葉脈 標本 葉脈 スマホ 新宿御苑 マルチディスプレイ ubuntu ubuntu マウス 感度 ケン ...

# %%
model = word2vec.Word2Vec(data, size=4, min_count=1)

# %%
model

# %%
out = model.most_similar(positive=[u''])
for x in out:
    print x[0], x[1]
# Out:
# dependency 0.993388295174
# joystick 0.99146258831
# LUCA 0.988250494003
# ウクライナ 0.987885594368
# anisotropic 0.987324476242
# wpa_supplicant 0.986540555954
# chromium 0.986263692379
# グローバル化 0.98458814621
# mv 0.984218597412
# ハイドロ 0.980878591537
